# %%
print("nihao zheshi w de dai ma")
result = 5 + 3
print(f"5 + 3 = {result}")
# Out:
# nihao zheshi w de dai ma
# 5 + 3 = 8

# %%
a = 10
b = 5
sum = a + b
print(f"a+b={sum}")
# Out:
# a+b=15

# %%
difference = a - b
print(f"a-b={difference}")
# Out:
# a-b=5
